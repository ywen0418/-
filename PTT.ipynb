# %%
import requests

# %%
cookies = {'cookie': '__cfduid=db7b21a061d141a5afbb7078ae7df46451573803772; _ga=GA1.2.648263617.1573803774; _gid=GA1.2.899122873.1594966712; __cf_bm=057bc0f6939fabbe871c8fb2ab4cd726e734691f-1594966713-1800-AYMxKnmgvJz39EV61gQInr+ihu0MN4s4xt8vOsjIVQ8cmzmDTPoRaSENG8DElzT9V0qhLmMBRdFkD7QCdeUVdKPleSvktX1OVBpWZmkdy4dGWESh1tcCrofPERb2nT9qHxUs6Y0woUn8JLERj4DMi+vpgjBTrKECjryidx8Q51Rk2OUoehpTcFzNuNjYT9q2eQ==; over18=1'}

# %%
ptt = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',cookies = cookies)
ptt.text
# Out:
# '<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">\n\n\n\n\n\t<script async src=\'/cdn-cgi/bm/cv/2172558837/api.js\'></script></head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/bbs/">批踢踢實業坊</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(ptt.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# <script async="" src="/cdn-cgi/bm/cv/2172558837/api.js"></script></head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup_title = soup.select('.title') #list
soup_title
# Out:
# [<div class="title">
#  <a href="/bbs/Gossiping/M.1594967243.A.5AF.html">[新聞] 再添2例菲律賓境外移入！20多歲女、40多歲男赴菲工作染疫</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967276.A.988.html">[問卦] 櫸坂是不是沒有平手友梨奈就不行了</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967280.A.CB9.html">[問卦] 請問蛾飛過山洞會變成什麼?</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967313.A.D77.html">[問卦] =.=臺灣哪個人跟香菜一樣噁心？！</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967348.A.072.html">[新聞] 立委投票紀錄遭疑作弊 立院：卡片誤插結</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967353.A.151.html">[新聞] 棒球看過程浪費時間？資深球迷陳佩琪曾透</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967363.A.5A3.html">[問卦] 搶到合一了，可以約妹了嗎？</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967459.A.A62.html">[問卦] 所以老人與海到底無不無聊？</a>
#  </div>, <div class="title">
#  <a href="/bbs/Gossiping/M.1594967461.A.661.html">[問卦] 老公告訴老婆他結紮可以預防被戴綠帽嗎?</a>
# ...

# %%
soup_title = soup.select('.title')
for a_tag in soup_title:
    if a_tag.select_one('a')!=None:
        print('===================')
        tag = a_tag.select_one('a')
        tag_harf='http://ptt.cc'+tag['href']
        print('網址',tag_harf)
        print('標題',tag.text)
# Out:
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967243.A.5AF.html
# 標題 [新聞] 再添2例菲律賓境外移入！20多歲女、40多歲男赴菲工作染疫
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967276.A.988.html
# 標題 [問卦] 櫸坂是不是沒有平手友梨奈就不行了
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967280.A.CB9.html
# 標題 [問卦] 請問蛾飛過山洞會變成什麼?
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967313.A.D77.html
# 標題 [問卦] =.=臺灣哪個人跟香菜一樣噁心？！
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967348.A.072.html
# 標題 [新聞] 立委投票紀錄遭疑作弊 立院：卡片誤插結
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967353.A.151.html
# 標題 [新聞] 棒球看過程浪費時間？資深球迷陳佩琪曾透
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967363.A.5A3.html
# 標題 [問卦] 搶到合一了，可以約妹了嗎？
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967459.A.A62.html
# 標題 [問卦] 所以老人與海到底無不無聊？
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967461.A.661.html
# 標題 [問卦] 老公告訴老婆他結紮可以預防被戴綠帽嗎?
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967496.A.45F.html
# 標題 [問卦] 少年阿賓484也很無聊?
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967500.A.6EB.html
# 標題 Re: [問卦] 當初kmt沒來台灣的話 我們現在是哪國
# ...
# 網址 http://ptt.cc/bbs/Gossiping/M.1594967506.A.7A1.html
# ...

# %%
context = requests.get('http://ppt.cc/bbs/Gossiping/M.1594967243.A.5AF.html')
context.text
# Out:
# '<html>\r\n\r\n<head>\r\n<meta http-equiv="Content-Language" content="zh-tw">\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n<meta name="description" content="PPT(ppt.cc) 短網址，不是 PTT (ptt.cc)唷，幫縮找我就對啦!">\r\n<meta name="keywords" content="短網址,縮網址,short,url,ppt,ptt,0rz,tinyurl,台泥,鄉民,縮址,幫縮">\r\n<link rel="shortcut icon" href="favicon.ico" />\r\n<link rel="stylesheet" href="bbs.css" type="text/css" />\r\n<title>來個 PPT 短網址 - 縮文章功能 (BBS版)</title>\r\n</head>\r\n<body bgcolor="#000000">\r\n<center><table border="0" cellspacing="0" cellpadding="0"><tr><td><pre>\n\n</pre></td></tr></table></center></body>\r\n</html>\r\n'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-612ae377f51f> in <module>
# ----> 1 article = soup.find(id="main-content").text
#
# AttributeError: 'NoneType' object has no attribute 'text'
